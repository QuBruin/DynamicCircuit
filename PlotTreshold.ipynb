# %%
from QEC.repetition import bitfliprepetitioncode
from Algorithm.noise import construct_bitflip_noise_model,construct_phaseflip_noise_model,construct_gate_bitflip_noise_model
import numpy as np

# %%
number_qubits=[3,5,7]
#physical_errorrates=[0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008]
physical_errorrates=list(np.linspace(0,0.02,30))

three_fidelity=[]
three_fidelity_notcorrect=[]
five_fidelity=[]
five_fidelity_notcorrect=[]
seven_fidelity=[]
seven_fidelity_notcorrect=[]
nine_fidelity=[]
nine_fidelity_notcorrect=[]
for num in number_qubits:
    for errorrate in physical_errorrates:
        rep=bitfliprepetitioncode(num)
        rep.set_benchmarkwidth(30)
        #noisemode=construct_gate_bitflip_noise_model(errorrate)
        noisemode=construct_bitflip_noise_model(errorrate,errorrate,3*errorrate)
        rep.construct_syndrome_table()
        #rep.show_syndrome_table()    
        rep.add_noise_model(noisemode)
        
        fidelity=rep.show_noise_effect(shots=100)    
        if num==3:
            three_fidelity.append(fidelity)
        if num==5:
            five_fidelity.append(fidelity)
        if num==7:
            seven_fidelity.append(fidelity)
        if num==9:
            nine_fidelity.append(fidelity)
# Out:
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']

# %%
        
for num in number_qubits:
    for errorrate in physical_errorrates:
        rep=bitfliprepetitioncode(num)
        rep.set_benchmarkwidth(10)
        rep.set_mutecorrection(True)
        #noisemode=construct_gate_bitflip_noise_model(errorrate)
        noisemode=construct_bitflip_noise_model(errorrate,0,errorrate)
        rep.construct_syndrome_table()
        #rep.show_syndrome_table()    
        rep.add_noise_model(noisemode)
        
        fidelity=rep.show_noise_effect(shots=100)    
        if num==3:
            three_fidelity_notcorrect.append(fidelity)
        if num==5:
            five_fidelity_notcorrect.append(fidelity)
        if num==7:
            seven_fidelity_notcorrect.append(fidelity)
        if num==9:
            nine_fidelity_notcorrect.append(fidelity)
# Out:
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZI', 'IZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIII', 'IZZII', 'IIZZI', 'IIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']
# ['ZZIIIII', 'IZZIIII', 'IIZZIII', 'IIIZZII', 'IIIIZZI', 'IIIIIZZ']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(physical_errorrates,three_fidelity,label="Three")
plt.plot(physical_errorrates,five_fidelity,label="Five")
plt.plot(physical_errorrates,seven_fidelity,label="Seven")
#plt.plot(physical_errorrates,nine_fidelity,label="Nine")
plt.legend()

# %%
plt.plot(physical_errorrates,five_fidelity,label="Five")
plt.plot(physical_errorrates,five_fidelity_notcorrect,label="Five not correct")
#plt.plot(physical_errorrates,five_fidelity,label="Five")
#plt.plot(physical_errorrates,seven_fidelity,label="Seven")
#plt.plot(physical_errorrates,nine_fidelity,label="Nine")
plt.legend()

# %%
rep=bitfliprepetitioncode(3)
rep.construct_syndrome_table()
rep.construct_circuit()
rep.circuit.draw(output='mpl')
# Out:
# ['ZZI', 'IZZ']
# C:\Users\73747\PycharmProjects\DynamicCircuit\yalehack\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
plt.plot(physical_errorrates,three_fidelity,label="Three")
plt.plot(physical_errorrates,three_fidelity_notcorrect,label="Three not correct")

# %%
rep=bitfliprepetitioncode(3)
rep.construct_syndrome_table()
rep.set_mutecorrection(True)
rep.set_benchmarkwidth(0)
rep.test_stabilizer_circuit("XXI")
# Out:
# ['ZZI', 'IZZ']
# The result is: 01 110
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 5
#       3 rep.set_mutecorrection(True)
#       4 rep.set_benchmarkwidth(0)
# ----> 5 rep.test_stabilizer_circuit("XXI")
#
# File ~\PycharmProjects\DynamicCircuit\QEC\QECCode.py:284, in QECCode.test_stabilizer_circuit(self, errorstr)
#     280 result=result[::-1]
#     281 print("The result is: "+result)
# --> 284 print("The expected rsult is "+self._symdrome_table[errorstr])
#     286 plot_histogram(counts)
#
# KeyError: 'XXI'
